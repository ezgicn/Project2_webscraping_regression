# %%
import math 
from matplotlib import pyplot
from numpy.random import normal
from numpy import hstack
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
from pandas import Series, DataFrame
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy
sns.set()
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV
from sklearn.metrics import r2_score

# %%
vakadf = pd.read_csv('C:/Users/EN/DataScienceAcademy/Project2/coviddata.csv')
last_data=vakadf["vaka"].iloc[-1]
new_data=[]

for i in range(0,373):
    last_data= last_data+1250
    new_data.append(last_data)
    
df2=pd.DataFrame(new_data,columns=["vaka"])
dff=pd.concat([vakadf,df2]) 
df3 = np.log(dff['vaka'])

# %%
##AKBANK
plt.figure(figsize=[8,10])
plt.subplot(2,2,1)
AKBNKşimdi1 = normal(loc=5.75, scale=0.25, size=450)
AKBNKşimdi2 = normal(loc=6.75, scale=0.25, size=50)
AKBNKşimdi = hstack((AKBNKşimdi1, AKBNKşimdi2))
sns.kdeplot(AKBNKşimdi)
plt.title('Şimdi',fontsize = 12, weight='bold')


plt.subplot(2,2,2)
AKBNKaçılış1 = normal(loc=5.85, scale=0.25, size=450)
AKBNKaçılış2 = normal(loc=6, scale=0.50, size=50)
AKBNKaçılış = hstack((AKBNKaçılış1, AKBNKaçılış2))
sns.kdeplot(AKBNKaçılış)
plt.title('Açılış',fontsize = 12, weight='bold')


plt.subplot(2,2,3)
AKBNKyüksek1 = normal(loc=5.90, scale=0.25, size=450)
AKBNKyüksek2 = normal(loc=6.60, scale=0.50, size=50)
AKBNKyüksek = hstack((AKBNKyüksek1, AKBNKyüksek2))
sns.kdeplot(AKBNKyüksek)
plt.title('Yüksek',fontsize = 12, weight='bold')

plt.subplot(2,2,4)
AKBNKdüşük1 = normal(loc=5.60, scale=0.25, size=450)
AKBNKdüşük2 = normal(loc=6.80, scale=0.30, size=50)
AKBNKdüşük = hstack((AKBNKdüşük1, AKBNKdüşük2))
sns.kdeplot(AKBNKdüşük)
plt.title('Düşük',fontsize = 12, weight='bold')
plt.suptitle('AKBANK',fontsize=20)
# Out:
# Text(0.5, 0.98, 'AKBANK')

# %%
###ALBARAKA
plt.figure(figsize=[8,10])
plt.subplot(2,2,1)
ALBRKşimdi1 = normal(loc=1.15, scale=0.10, size=300)
ALBRKşimdi2 = normal(loc=1.60, scale=0.25, size=200)
ALBRKşimdi = np.log(hstack((ALBRKşimdi1, ALBRKşimdi2)))
sns.kdeplot(ALBRKşimdi)
plt.title('Şimdi',fontsize = 12, weight='bold')

plt.subplot(2,2,2)
ALBRKaçılış1 = normal(loc=1.15, scale=0.10, size=300)
ALBRKaçılış2 = normal(loc=1.60, scale=0.25, size=200)
ALBRKaçılış = hstack((ALBRKaçılış1, ALBRKaçılış2))
sns.kdeplot(ALBRKaçılış)
plt.title('Açılış',fontsize = 12, weight='bold')

plt.subplot(2,2,3)
ALBRKyüksek1 = normal(loc=1.15, scale=0.10, size=300)
ALBRKyüksek2 = normal(loc=1.65, scale=0.25, size=200)
ALBRKyüksek = hstack((ALBRKyüksek1, ALBRKyüksek2))
sns.kdeplot(ALBRKyüksek)
plt.title('Yüksek',fontsize = 12, weight='bold')

plt.subplot(2,2,4)
ALBRKdüşük1 = normal(loc=1.05, scale=0.10, size=300)
ALBRKdüşük2 = normal(loc=1.55, scale=0.25, size=200)
ALBRKdüşük = hstack((ALBRKdüşük1, ALBRKdüşük2))
sns.kdeplot(ALBRKdüşük)
plt.title('Düşük',fontsize = 12, weight='bold')
plt.suptitle('ALBARAKA',fontsize=20)
# Out:
# Text(0.5, 0.98, 'ALBARAKA')

# %%
####GARANTİ
plt.figure(figsize=[8,10])
plt.subplot(2,2,1)
GARANşimdi1 = normal(loc=1.15, scale=0.10, size=300)
GARANşimdi2 = normal(loc=1.60, scale=0.25, size=200)
GARANşimdi = hstack((GARANşimdi1, GARANşimdi2))
sns.kdeplot(GARANşimdi)
plt.title('Şimdi',fontsize = 12, weight='bold')

plt.subplot(2,2,2)
GARANaçılış1 = normal(loc=1.15, scale=0.10, size=300)
GARANaçılış2 = normal(loc=1.60, scale=0.25, size=200)
GARANaçılış = hstack((GARANaçılış1, GARANaçılış2))
sns.kdeplot(GARANaçılış)
plt.title('Açılış',fontsize = 12, weight='bold')

plt.subplot(2,2,3)
GARANyüksek1 = normal(loc=1.15, scale=0.10, size=300)
GARANyüksek2 = normal(loc=1.65, scale=0.25, size=200)
GARANyüksek = hstack((GARANyüksek1, GARANyüksek2))
sns.kdeplot(GARANyüksek)
plt.title('Yüksek',fontsize = 12, weight='bold')

plt.subplot(2,2,4)
GARANdüşük1 = normal(loc=1.05, scale=0.10, size=300)
GARANdüşük2 = normal(loc=1.55, scale=0.25, size=200)
GARANdüşük = hstack((GARANdüşük1, GARANdüşük2))
sns.kdeplot(GARANdüşük)
plt.title('Düşük',fontsize = 12, weight='bold')
plt.suptitle('GARANTİ',fontsize=20)
# Out:
# Text(0.5, 0.98, 'GARANTİ')

# %%
####YAPIKREDİ
plt.figure(figsize=[8,10])
plt.subplot(2,2,1)
YKBNKşimdi1 = normal(loc=2.1, scale=0.15, size=235)
YKBNKşimdi2 = normal(loc=2.35, scale=0.25, size=265)
YKBNKşimdi = hstack((YKBNKşimdi1, YKBNKşimdi2))
sns.kdeplot(YKBNKşimdi)
plt.title('Şimdi',fontsize = 12, weight='bold')

plt.subplot(2,2,2)
YKBNKaçılış1 = normal(loc=2.0, scale=0.15, size=235)
YKBNKaçılış2 = normal(loc=2.3, scale=0.2, size=265)
YKBNKaçılış = hstack((YKBNKaçılış1, YKBNKaçılış2))
sns.kdeplot(YKBNKaçılış)
plt.title('Açılış',fontsize = 12, weight='bold')

plt.subplot(2,2,3)
YKBNKyüksek1 = normal(loc=2.2, scale=0.15, size=235)
YKBNKyüksek2 = normal(loc=2.4, scale=0.2, size=265)
YKBNKyüksek = hstack((YKBNKyüksek1, YKBNKyüksek2))
sns.kdeplot(YKBNKyüksek)
plt.title('Yüksek',fontsize = 12, weight='bold')

plt.subplot(2,2,4)
YKBNKdüşük1 = normal(loc=1.9, scale=0.15, size=235)
YKBNKdüşük2 = normal(loc=2.35, scale=0.2, size=265)
YKBNKdüşük = hstack((YKBNKdüşük1, YKBNKdüşük2))
sns.kdeplot(YKBNKdüşük)
plt.title('Düşük',fontsize = 12, weight='bold')
plt.suptitle('YAPIKREDİ',fontsize=20)
# Out:
# Text(0.5, 0.98, 'YAPIKREDİ')

# %%
####QNBFİNANS
plt.figure(figsize=[8,10])
plt.subplot(2,2,1)
QNBFBşimdi1 = normal(loc=33, scale=5, size=150)
QNBFBşimdi2 = normal(loc=49, scale=3, size=350)
QNBFBşimdi = hstack((QNBFBşimdi1, QNBFBşimdi2))
sns.kdeplot(QNBFBşimdi)
plt.title('Şimdi',fontsize = 12, weight='bold')

plt.subplot(2,2,2)
QNBFBaçılış1 = normal(loc=32, scale=5, size=150)
QNBFBaçılış2 = normal(loc=49, scale=3, size=350)
QNBFBaçılış = hstack((QNBFBaçılış1, QNBFBaçılış2))
sns.kdeplot(QNBFBaçılış)
plt.title('Açılış',fontsize = 12, weight='bold')

plt.subplot(2,2,3)
QNBFByüksek1 = normal(loc=35, scale=5, size=150)
QNBFByüksek2 = normal(loc=50, scale=3, size=350)
QNBFByüksek = hstack((QNBFByüksek1, QNBFByüksek2))
sns.kdeplot(QNBFByüksek)
plt.title('Yüksek',fontsize = 12, weight='bold')

plt.subplot(2,2,4)
QNBFBdüşük1 = normal(loc=31, scale=5, size=150)
QNBFBdüşük2 = normal(loc=48, scale=3, size=350)
QNBFBdüşük = hstack((QNBFBdüşük1, QNBFBdüşük2))
sns.kdeplot(QNBFBdüşük)
plt.title('Düşük',fontsize = 12, weight='bold')
plt.suptitle('QNBFİNANSBANK',fontsize=20)
# Out:
# Text(0.5, 0.98, 'QNBFİNANSBANK')

# %%
####VAKIFBANK
plt.figure(figsize=[8,10])
plt.subplot(2,2,1)
VAKBNşimdi1 = normal(loc=4.7, scale=0.20, size=350)
VAKBNşimdi2 = normal(loc=5.1, scale=0.35, size=150)
VAKBNşimdi = hstack((VAKBNşimdi1, VAKBNşimdi2))
sns.kdeplot(VAKBNşimdi)
plt.title('Şimdi',fontsize = 12, weight='bold')

plt.subplot(2,2,2)
VAKBNaçılış1 = normal(loc=4.6, scale=0.20, size=350)
VAKBNaçılış2 = normal(loc=5.4, scale=0.35, size=150)
VAKBNaçılış = hstack((VAKBNaçılış1, VAKBNaçılış2))
sns.kdeplot(VAKBNaçılış)
plt.title('Açılış',fontsize = 12, weight='bold')

plt.subplot(2,2,3)
VAKBNyüksek1 = normal(loc=4.8, scale=0.20, size=350)
VAKBNyüksek2 = normal(loc=5.3, scale=0.35, size=150)
VAKBNyüksek = hstack((VAKBNyüksek1, VAKBNyüksek2))
sns.kdeplot(VAKBNyüksek)
plt.title('Yüksek',fontsize = 12, weight='bold')

plt.subplot(2,2,4)
VAKBNdüşük1 = normal(loc=4.5, scale=0.20, size=350)
VAKBNdüşük2 = normal(loc=5.2, scale=0.35, size=150)
VAKBNdüşük = hstack((VAKBNdüşük1, VAKBNdüşük2))
sns.kdeplot(VAKBNdüşük)
plt.title('Düşük',fontsize = 12, weight='bold')
plt.suptitle('VAKIFBANK',fontsize=20)
# Out:
# Text(0.5, 0.98, 'VAKIFBANK')

# %%
####Gold(altın)
plt.figure(figsize=[8,10])
plt.subplot(2,2,1)
Altınşimdi1 = normal(loc=1490, scale=30, size=100)
Altınşimdi2 = normal(loc=1730, scale=20, size=400)
Altınşimdi = np.log(hstack((Altınşimdi1, Altınşimdi2)))
sns.kdeplot(Altınşimdi)
plt.title('Şimdi',fontsize = 12, weight='bold')

plt.subplot(2,2,2)
Altınaçılış1 = normal(loc=1500, scale=30, size=100)
Altınaçılış2 = normal(loc=1750, scale=20, size=400)
Altınaçılış = np.log(hstack((Altınaçılış1, Altınaçılış2)))
sns.kdeplot(Altınaçılış)
plt.title('Açılış',fontsize = 12, weight='bold')

plt.subplot(2,2,3)
Altınyüksek1 = normal(loc=1550, scale=30, size=100)
Altınyüksek2 = normal(loc=1780, scale=20, size=400)
Altınyüksek = hstack((Altınyüksek1, Altınyüksek2))
sns.kdeplot(Altınyüksek)
plt.title('Yüksek',fontsize = 12, weight='bold')

plt.subplot(2,2,4)
Altındüşük1 = normal(loc=1480, scale=30, size=100)
Altındüşük2 = normal(loc=1720, scale=20, size=400)
Altındüşük = np.log(hstack((Altındüşük1, Altındüşük2)))
sns.kdeplot(Altındüşük)
plt.title('Düşük',fontsize = 12, weight='bold')
plt.suptitle('Altın',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Altın')

# %%
####Silver(Gümüş)
plt.figure(figsize=[8,10])
plt.subplot(2,2,1)
Gümüşşimdi1 = normal(loc=15, scale=0.75, size=225)
Gümüşşimdi2 = normal(loc=18, scale=1, size=275)
Gümüşşimdi = hstack((Gümüşşimdi1, Gümüşşimdi2))
sns.kdeplot(Gümüşşimdi)
plt.title('Şimdi',fontsize = 12, weight='bold')

plt.subplot(2,2,2)
Gümüşaçılış1 = normal(loc=15, scale=0.75, size=225)
Gümüşaçılış2 = normal(loc=18, scale=1, size=275)
Gümüşaçılış = hstack((Gümüşaçılış1, Gümüşaçılış2))
sns.kdeplot(Gümüşaçılış)
plt.title('Açılış',fontsize = 12, weight='bold')

plt.subplot(2,2,3)
Gümüşyüksek1 = normal(loc=15.75, scale=0.75, size=225)
Gümüşyüksek2 = normal(loc=18.5, scale=1, size=275)
Gümüşyüksek = hstack((Gümüşyüksek1, Gümüşyüksek2))
sns.kdeplot(Gümüşyüksek)
plt.title('Yüksek',fontsize = 12, weight='bold')

plt.subplot(2,2,4)
Gümüşdüşük1 = normal(loc=14.5, scale=0.75, size=225)
Gümüşdüşük2 = normal(loc=17.5, scale=1, size=275)
Gümüşdüşük = hstack((Gümüşdüşük1, Gümüşdüşük2))
sns.kdeplot(Gümüşdüşük)
plt.title('Düşük',fontsize = 12, weight='bold')
plt.suptitle('Gümüş',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Gümüş')

# %%
####Brent petrol
plt.figure(figsize=[8,10])
plt.subplot(2,2,1)
Brentşimdi1 = normal(loc=30, scale=5, size=225)
Brentşimdi2 = normal(loc=32, scale=2, size=275)
Brentşimdi = hstack((Brentşimdi1, Brentşimdi2))
sns.kdeplot(Brentşimdi)
plt.title('Şimdi',fontsize = 12, weight='bold')

plt.subplot(2,2,2)
Brentaçılış1 = normal(loc=30, scale=4, size=225)
Brentaçılış2 = normal(loc=33, scale=2, size=275)
Brentaçılış = hstack((Brentaçılış1, Brentaçılış2))
sns.kdeplot(Brentaçılış)
plt.title('Açılış',fontsize = 12, weight='bold')

plt.subplot(2,2,3)
Brentyüksek1 = normal(loc=35, scale=4, size=225)
Brentyüksek2 = normal(loc=35, scale=2, size=275)
Brentyüksek = hstack((Brentyüksek1, Brentyüksek2))
sns.kdeplot(Brentyüksek)
plt.title('Yüksek',fontsize = 12, weight='bold')

plt.subplot(2,2,4)
Brentdüşük1 = normal(loc=28, scale=3, size=275)
Brentdüşük2 = normal(loc=38, scale=3, size=225)
Brentdüşük = hstack((Brentdüşük1, Brentdüşük2))
sns.kdeplot(Brentdüşük)
plt.title('Düşük',fontsize = 12, weight='bold')
plt.suptitle('Brent',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Brent')

# %%
####USD
plt.figure(figsize=[8,10])
plt.subplot(2,2,1)
USDşimdi1 = normal(loc=6.4, scale=0.25, size=150)
USDşimdi2 = normal(loc=6.8, scale=0.10, size=350)
USDşimdi = hstack((USDşimdi1, USDşimdi2))
sns.kdeplot(USDşimdi)
plt.title('Şimdi',fontsize = 12, weight='bold')

plt.subplot(2,2,2)
USDaçılış1 = normal(loc=6.4, scale=0.25, size=150)
USDaçılış2 = normal(loc=6.8, scale=0.10, size=350)
USDaçılış = hstack((USDaçılış1, USDaçılış2))
sns.kdeplot(USDaçılış)
plt.title('Açılış',fontsize = 12, weight='bold')

plt.subplot(2,2,3)
USDyüksek1 = normal(loc=6.5, scale=0.25, size=150)
USDyüksek2 = normal(loc=6.9, scale=0.10, size=350)
USDyüksek = hstack((USDyüksek1, USDyüksek2))
sns.kdeplot(USDyüksek)
plt.title('Yüksek',fontsize = 12, weight='bold')

plt.subplot(2,2,4)
USDdüşük1 = normal(loc=6.3, scale=0.25, size=150)
USDdüşük2 = normal(loc=6.7, scale=0.10, size=350)
USDdüşük = hstack((USDdüşük1, USDdüşük2))
sns.kdeplot(USDdüşük)
plt.title('Düşük',fontsize = 12, weight='bold')
plt.suptitle('Dolar',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Dolar')

# %%
####Euro
plt.figure(figsize=[8,10])
plt.subplot(2,2,1)
Euroşimdi1 = normal(loc=6.4, scale=0.25, size=150)
Euroşimdi2 = normal(loc=6.8, scale=0.10, size=350)
Euroşimdi = hstack((Euroşimdi1, Euroşimdi2))
sns.kdeplot(Euroşimdi)
plt.title('Şimdi',fontsize = 12, weight='bold')

plt.subplot(2,2,2)
Euroaçılış1 = normal(loc=6.4, scale=0.25, size=150)
Euroaçılış2 = normal(loc=6.8, scale=0.10, size=350)
Euroaçılış = hstack((Euroaçılış1, Euroaçılış2))
sns.kdeplot(Euroaçılış)
plt.title('Açılış',fontsize = 12, weight='bold')

plt.subplot(2,2,3)
Euroyüksek1 = normal(loc=6.5, scale=0.25, size=150)
Euroyüksek2 = normal(loc=6.9, scale=0.10, size=350)
Euroyüksek = hstack((Euroyüksek1, Euroyüksek2))
sns.kdeplot(Euroyüksek)
plt.title('Yüksek',fontsize = 12, weight='bold')

plt.subplot(2,2,4)
Eurodüşük1 = normal(loc=6.3, scale=0.25, size=150)
Eurodüşük2 = normal(loc=6.7, scale=0.10, size=350)
Eurodüşük = hstack((Eurodüşük1, Eurodüşük2))
sns.kdeplot(Eurodüşük)
plt.title('Düşük',fontsize = 12, weight='bold')
plt.suptitle('Euro',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Euro')

# %%
####GBP
plt.figure(figsize=[8,10])
plt.subplot(2,2,1)
GBPşimdi1 = normal(loc=7.75, scale=0.25, size=150)
GBPşimdi2 = normal(loc=8.65, scale=0.10, size=350)
GBPşimdi = hstack((GBPşimdi1, GBPşimdi2))
sns.kdeplot(GBPşimdi)
plt.title('Şimdi',fontsize = 12, weight='bold')

plt.subplot(2,2,2)
GBPaçılış1 = normal(loc=7.5, scale=0.25, size=150)
GBPaçılış2 = normal(loc=8.5, scale=0.10, size=350)
GBPaçılış = hstack((GBPaçılış1, GBPaçılış2))
sns.kdeplot(GBPaçılış)
plt.title('Açılış',fontsize = 12, weight='bold')

plt.subplot(2,2,3)
GBPyüksek1 = normal(loc=7.7, scale=0.25, size=150)
GBPyüksek2 = normal(loc=8.7, scale=0.10, size=350)
GBPyüksek = hstack((GBPyüksek1, GBPyüksek2))
sns.kdeplot(GBPyüksek)
plt.title('Yüksek',fontsize = 12, weight='bold')

plt.subplot(2,2,4)
GBPdüşük1 = normal(loc=7.4, scale=0.25, size=150)
GBPdüşük2 = normal(loc=8.5, scale=0.10, size=350)
GBPdüşük = hstack((GBPdüşük1, GBPdüşük2))
sns.kdeplot(GBPdüşük)
plt.title('Düşük',fontsize = 12, weight='bold')
plt.suptitle('Sterlin',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Sterlin')

# %%
####Bitcoin
plt.figure(figsize=[8,10])
plt.subplot(2,2,1)
BTCşimdi1 = normal(loc=42000, scale=4500, size=200)
BTCşimdi2 = normal(loc=70000, scale=4500, size=300)
BTCşimdi = hstack((BTCşimdi1, BTCşimdi2))
sns.kdeplot(BTCşimdi)
plt.title('Şimdi',fontsize = 12, weight='bold')

plt.subplot(2,2,2)
BTCaçılış1 = normal(loc=42000, scale=4500, size=200)
BTCaçılış2 = normal(loc=70000, scale=4500, size=300)
BTCaçılış = hstack((BTCaçılış1, BTCaçılış2))
sns.kdeplot(BTCaçılış)
plt.title('Açılış',fontsize = 12, weight='bold')

plt.subplot(2,2,3)
BTCyüksek1 = normal(loc=42500, scale=4500, size=200)
BTCyüksek2 = normal(loc=71000, scale=4500, size=300)
BTCyüksek = hstack((BTCyüksek1, BTCyüksek2))
sns.kdeplot(BTCyüksek)
plt.title('Yüksek',fontsize = 12, weight='bold')

plt.subplot(2,2,4)
BTCdüşük1 = normal(loc=42000, scale=4500, size=200)
BTCdüşük2 = normal(loc=70000, scale=4500, size=300)
BTCdüşük = hstack((BTCdüşük1, BTCdüşük2))
sns.kdeplot(BTCdüşük)
plt.title('Düşük',fontsize = 12, weight='bold')
plt.suptitle('Bitcoin',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Bitcoin')

# %%
data = {'df3':list(np.asarray(df3).reshape(-1)),
        'AKBNKşimdi':list(np.asarray(AKBNKşimdi).reshape(-1)),
        'AKBNKaçılış':list(np.asarray(AKBNKaçılış).reshape(-1)),
        'AKBNKyüksek':list(np.asarray(AKBNKyüksek).reshape(-1)),
        'AKBNKdüşük':list(np.asarray(AKBNKyüksek).reshape(-1)),
        'ALBRKşimdi':list(np.asarray(ALBRKşimdi).reshape(-1)),
        'ALBRKaçılış':list(np.asarray(ALBRKaçılış).reshape(-1)),
        'ALBRKyüksek':list(np.asarray(ALBRKyüksek).reshape(-1)),
        'ALBRKdüşük':list(np.asarray(ALBRKdüşük).reshape(-1)),
        'GARANşimdi':list(np.asarray(GARANşimdi).reshape(-1)),
        'GARANaçılış':list(np.asarray(GARANaçılış).reshape(-1)),
        'GARANyüksek':list(np.asarray(GARANyüksek).reshape(-1)),
        'GARANdüşük':list(np.asarray(GARANdüşük).reshape(-1)),
        'YKBNKşimdi':list(np.asarray(YKBNKşimdi).reshape(-1)),
        'YKBNKaçılış':list(np.asarray(YKBNKaçılış).reshape(-1)),
        'YKBNKyüksek':list(np.asarray(YKBNKyüksek).reshape(-1)),
        'YKBNKdüşük':list(np.asarray(YKBNKdüşük).reshape(-1)),
        'QNBFBşimdi':list(np.asarray(QNBFBşimdi).reshape(-1)),
        'QNBFBaçılış':list(np.asarray(QNBFBaçılış).reshape(-1)),
        'QNBFByüksek':list(np.asarray(QNBFByüksek).reshape(-1)),
        'QNBFBdüşük':list(np.asarray(QNBFBdüşük).reshape(-1)),
        'VAKBNşimdi':list(np.asarray(VAKBNşimdi).reshape(-1)),
        'VAKBNaçılış':list(np.asarray(VAKBNaçılış).reshape(-1)),
        'VAKBNyüksek':list(np.asarray(VAKBNyüksek).reshape(-1)),
        'VAKBNdüşük':list(np.asarray(VAKBNdüşük).reshape(-1)),
        'Altınşimdi':list(np.asarray(Altınşimdi).reshape(-1)),
        'Altınaçılış':list(np.asarray(Altınaçılış).reshape(-1)),
        'Altınyüksek':list(np.asarray(Altınyüksek).reshape(-1)),
        'Altındüşük':list(np.asarray(Altındüşük).reshape(-1)),
        'Gümüşşimdi':list(np.asarray(Gümüşşimdi).reshape(-1)),
        'Gümüşaçılış':list(np.asarray(Gümüşaçılış).reshape(-1)),
        'Gümüşyüksek':list(np.asarray(Gümüşyüksek).reshape(-1)),
        'Gümüşdüşük':list(np.asarray(Gümüşdüşük).reshape(-1)),
        'Brentşimdi':list(np.asarray(Brentşimdi).reshape(-1)),
        'Brentaçılış':list(np.asarray(Brentaçılış).reshape(-1)),
        'Brentyüksek':list(np.asarray(Brentyüksek).reshape(-1)),
        'Brentdüşük':list(np.asarray(Brentdüşük).reshape(-1)),
        'USDşimdi':list(np.asarray(USDşimdi).reshape(-1)),
        'USDaçılış':list(np.asarray(USDaçılış).reshape(-1)),
        'USDyüksek':list(np.asarray(USDyüksek).reshape(-1)),
        'USDdüşük':list(np.asarray(USDdüşük).reshape(-1)),
        'Euroşimdi':list(np.asarray(Euroşimdi).reshape(-1)),
        'Euroaçılış':list(np.asarray(Euroaçılış).reshape(-1)),
        'Euroyüksek':list(np.asarray(Euroyüksek).reshape(-1)),
        'Eurodüşük':list(np.asarray(Eurodüşük).reshape(-1)),
        'GBPşimdi':list(np.asarray(GBPşimdi).reshape(-1)),
        'GBPaçılış':list(np.asarray(GBPaçılış).reshape(-1)),
        'GBPyüksek':list(np.asarray(GBPyüksek).reshape(-1)),
        'GBPdüşük':list(np.asarray(GBPdüşük).reshape(-1)),
        'BTCşimdi':list(np.asarray(BTCşimdi).reshape(-1)),
        'BTCaçılış':list(np.asarray(BTCaçılış).reshape(-1)),
        'BTCyüksek':list(np.asarray(BTCyüksek).reshape(-1)),
        'BTCdüşük':list(np.asarray(BTCdüşük).reshape(-1)),
        }
a=[]
for i in range(0,500):
   a.append(str(i))
df = pd.DataFrame(data)

# %%
dfbank= [df['AKBNKaçılış'], df['AKBNKyüksek'], df['AKBNKdüşük'], df['QNBFBaçılış'], df['QNBFByüksek'], df['QNBFBdüşük'],
        df['ALBRKaçılış'], df['ALBRKyüksek'], df['ALBRKdüşük'], df['GARANaçılış'], df['GARANyüksek'], df['GARANdüşük'],
        df['VAKBNaçılış'], df['VAKBNdüşük'], df['Altınyüksek'], df['YKBNKaçılış'], df['YKBNKyüksek'], df['YKBNKdüşük']]
headersbank = ['AKBNKaçılış','AKBNKyüksek', 'AKBNKdüşük','QNBFBaçılış', 'QNBFByüksek', 'QNBFBdüşük',
               'ALBRKaçılış', 'ALBRKyüksek', 'ALBRKdüşük', 'GARANaçılış', 'GARANyüksek', 'GARANdüşük',
               'VAKBNaçılış', 'Altınyüksek', 'VAKBNdüşük', 'YKBNKaçılış', 'YKBNKyüksek', 'YKBNKdüşük']
dfbankkor= pd.concat(dfbank, axis=1, keys=headersbank)
kor1=dfbankkor.corr()
sns.heatmap(kor1)

dfemtia= [df['Altınaçılış'], df['Altınyüksek'], df['Altındüşük'], df['Gümüşaçılış'], df['Gümüşyüksek'], df['Gümüşdüşük'],
          df['Brentaçılış'], df['Brentyüksek'], df['Brentdüşük'], df['USDaçılış'], df['USDyüksek'], df['USDdüşük'],
          df['Euroaçılış'], df['Eurodüşük'], df['Euroyüksek'], df['GBPaçılış'], df['GBPyüksek'], df['GBPdüşük'],
          df['BTCaçılış'], df['BTCyüksek'], df['BTCdüşük']]
headersemtia = ['Altınaçılış','Altınyüksek', 'Altındüşük', 'Gümüşaçılış', 'Gümüşyüksek', 'Gümüşdüşük',
                'Brentaçılış', 'Brentyüksek', 'Brentdüşük', 'USDaçılış', 'USDyüksek', 'USDdüşük','Euroaçılış', 
                'Eurodüşük', 'Euroyüksek', 'GBPaçılış', 'GBPyüksek', 'GBPdüşük', 'BTCaçılış', 'BTCyüksek', 'BTCdüşük']
dfemtiakor= pd.concat(dfemtia, axis=1, keys=headersemtia)
kor2=dfemtiakor.corr()
sns.heatmap(kor2)

# %%
###AKBANK closing price estimation model
XAK = df.loc[:,['df3', 'YKBNKaçılış', 'YKBNKyüksek', 'YKBNKdüşük', 'AKBNKaçılış', 'AKBNKyüksek', 'AKBNKdüşük','ALBRKaçılış', 
                'ALBRKyüksek', 'ALBRKdüşük','GARANaçılış', 'GARANyüksek', 'GARANdüşük', 'QNBFBaçılış', 'QNBFByüksek', 
                'QNBFBdüşük', 'VAKBNaçılış', 'VAKBNyüksek', 'VAKBNdüşük', 'Altınaçılış', 'Altınyüksek', 'Altındüşük',
                'Gümüşaçılış', 'Gümüşyüksek', 'Gümüşdüşük', 'Brentaçılış', 'Brentyüksek', 'Brentdüşük', 'USDaçılış',
                'USDyüksek', 'USDdüşük', 'Euroaçılış', 'Euroyüksek', 'Eurodüşük', 'GBPaçılış', 'GBPyüksek', 'GBPdüşük', 
                'BTCaçılış', 'BTCyüksek', 'BTCdüşük']]
yAK = df['AKBNKşimdi']

# %%
###Testing linear regression assumptions ###
### 1)Data was generated from Normal distribution
### 2)Normallity test for residuals 
lrAK = LinearRegression()
fitAK = lrAK.fit(XAK,yAK)
df['predict']=fitAK.predict(XAK)
df['resid']=yAK-df.predict
with sns.axes_style('white'):
    plot=df.plot(kind='scatter',
                  x='predict',y='resid',alpha=0.2,figsize=(10,6))
yAK.hist(bins=35)
plt.title('Histogram of Dependent Variable (User Counts)');
stats.probplot(df['resid'], dist="norm", plot=plt)
plt.title("Normal Q-Q plot")
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
modelAK = sm.OLS(yAK,XAK)
fitAK = modelAK.fit()
fitAK.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             AKBNKşimdi   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              3913.
# Date:                Mon, 20 Jul 2020   Prob (F-statistic):                        0.00
# Time:                        12:31:01   Log-Likelihood:                         -144.31
# No. Observations:                 500   AIC:                                      366.6
# Df Residuals:                     461   BIC:                                      531.0
# Df Model:                          39
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
### 3) Homoscedasticity test for residuals
df['predict']=fitAK.predict(XAK)
df['resid']= yAK-df.predict
with sns.axes_style('white'):
    plot = df.plot(
        kind='scatter', x='predict', y='resid', alpha=0.5, figsize=(10,6))
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
### 4) Detecting correlation between residuals and observations
dfresAK= [df['AKBNKaçılış'], df['AKBNKyüksek'], df['AKBNKdüşük'],df['resid']]
headersAK = ['AKBNKaçılış', 'AKBNKyüksek', 'AKBNKdüşük','Residual']
resdfAK= pd.concat(dfresAK, axis=1, keys=headersAK)
korAKres=resdfAK.corr()
sns.heatmap(korAKres)

# %%
### 5) Multicollinearity test according to Condition Number
modelAK = sm.OLS(yAK,XAK)
fitAK = modelAK.fit()
fitAK.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:             AKBNKşimdi   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              3913.
# Date:                Mon, 20 Jul 2020   Prob (F-statistic):                        0.00
# Time:                        14:51:23   Log-Likelihood:                         -144.31
# No. Observations:                 500   AIC:                                      366.6
# Df Residuals:                     461   BIC:                                      531.0
# Df Model:                          39
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
XAK_train_val, XAK_test, yAK_train_val, yAK_test = train_test_split(XAK, yAK, test_size=0.2,random_state=42)
XAK_train, XAK_val, yAK_train, yAK_val = train_test_split(XAK_train_val, yAK_train_val, test_size=0.2, random_state=43)
### AKBANK lineer regression ###
lregAK = LinearRegression()
lregAK.fit(XAK_train,yAK_train)
lregpredAK = lregAK.predict(XAK_val)
lregmseAK = np.mean((lregpredAK - yAK_val)**2)
print(lregAK.score(XAK_val, yAK_val))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-aa2217363e45> in <module>
# ----> 1 XAK_train_val, XAK_test, yAK_train_val, yAK_test = train_test_split(XAK, yAK, test_size=0.2,random_state=42)
#       2 XAK_train, XAK_val, yAK_train, yAK_val = train_test_split(XAK_train_val, yAK_train_val, test_size=0.2, random_state=43)
#
# NameError: name 'XAK' is not defined

# %% [markdown]
# Cond.No. is 1.52e+16 and indicated that there is perfect multicollinearity. Thus, Ridge regression will use future steps and the results will be compared with Lasso.

# %%
##Polynomial effects were added into the regression model and seen that R2 become higher.
XAK['AKBNKyüksek2'] = XAK['AKBNKyüksek'] ** 2

### AKBANK Ridge and Lasso Regression###
alphaAK = 10**np.linspace(-5,10,100)
lasso_AK = LassoCV(alphas = alphaAK, cv=10)
lasso_AK.fit(XAK_train, yAK_train)
lasso_model_AK = Lasso(alpha = lasso_AK.alpha_) 
lasso_model_AK.fit(XAK_train, yAK_train)
pred_lasso_AK = lasso_AK.predict(XAK_test)
print(list(zip(XAK_train.columns, lasso_model_AK.coef_)))

def mae(yAK_true, yAK_pred):
   return np.mean(np.abs(yAK_pred - yAK_true)) 

print(mae(yAK_test, pred_lasso_AK))
print(r2_score(yAK_test, pred_lasso_AK))

alphavecridgeAK = 10**np.linspace(1,20,100)
ridge_AK = RidgeCV(alphas = alphavecridgeAK, cv=10) 
ridge_AK.fit(XAK_train, yAK_train)
print(list(zip(XAK_test.columns, ridge_AK.coef_)))
pred_ridge_AK = ridge_AK.predict(XAK_test)
lr_AK_ridge = Ridge(alpha = ridge_AK.alpha_)
print(r2_score(yAK_test, pred_ridge_AK))
# Out:
# [('df3', -0.004885831006675669), ('YKBNKaçılış', -0.0), ('YKBNKyüksek', -0.0), ('YKBNKdüşük', -0.0), ('AKBNKaçılış', -0.0), ('AKBNKyüksek', 0.42484236820965104), ('AKBNKdüşük', 4.469130363694924e-15), ('ALBRKaçılış', 0.0), ('ALBRKyüksek', 0.0), ('ALBRKdüşük', 0.0), ('GARANaçılış', 0.0), ('GARANyüksek', 0.0), ('GARANdüşük', 0.0), ('QNBFBaçılış', 0.0), ('QNBFByüksek', 0.006051054108103499), ('QNBFBdüşük', -0.0053981998627689945), ('VAKBNaçılış', 0.0), ('VAKBNyüksek', 0.0), ('VAKBNdüşük', 0.0), ('Altınaçılış', -0.0), ('Altınyüksek', 7.366723662612749e-05), ('Altındüşük', 0.0), ('Gümüşaçılış', 0.002207231229770551), ('Gümüşyüksek', 0.0), ('Gümüşdüşük', 0.0047304405127061855), ('Brentaçılış', 0.0), ('Brentyüksek', -0.008877607552068845), ('Brentdüşük', 0.0033091181319329444), ('USDaçılış', 0.0), ('USDyüksek', -0.0), ('USDdüşük', -0.0), ('Euroaçılış', 0.0), ('Euroyüksek', -0.0), ('Eurodüşük', -0.0), ('GBPaçılış', -0.0), ('GBPyüksek', -0.0), ('GBPdüşük', -0.0), ('BTCaçılış', 3.0510860272882
# ...

# %%
### ALBARAKA Ridge and Lasso Regression###
XAL = df.loc[:,['df3', 'ALBRKaçılış', 'ALBRKyüksek', 'ALBRKdüşük', 'AKBNKaçılış', 'GARANaçılış', 'GARANyüksek','YKBNKaçılış', 
               'QNBFBaçılış', 'QNBFByüksek', 'QNBFBdüşük', 'VAKBNaçılış', 'VAKBNyüksek', 'Altınyüksek', 'Gümüşaçılış', 
               'Gümüşyüksek', 'Gümüşdüşük', 'Brentaçılış', 'Brentyüksek', 'Brentdüşük', 'Euroaçılış', 'GBPyüksek', 'GBPdüşük', 
               'BTCaçılış', 'BTCyüksek', 'BTCdüşük']]
XAL['ALBARAKAaçılış3'] = (XAL['ALBRKyüksek'] **1/2) + XAL['ALBRKaçılış'] ** 3 
yAL = df['ALBRKşimdi']
XAL_train_val, XAL_test, yAL_train_val, yAL_test = train_test_split(XAL, yAL, test_size=0.2,random_state=42)
XAL_train, XAL_val, yAL_train, yAL_val = train_test_split(XAL_train_val, yAL_train_val, test_size=0.2, random_state=43)
alphaAL = 10**np.linspace(-5,15,2000)
lasso_AL = LassoCV(alphas = alphaAL, cv=10)
lasso_AL.fit(XAL_train, yAL_train)
lasso_model_AL = Lasso(alpha = lasso_AL.alpha_) 
lasso_model_AL.fit(XAL_train, yAL_train)
pred_lasso_AL = lasso_AL.predict(XAL_test)
print(list(zip(XAL_train.columns, lasso_model_AL.coef_)))

def mae(yAL_true, yAL_pred):
    return np.mean(np.abs(yAL_pred - yAL_true)) 

print(mae(yAL_test, pred_lasso_AL))
print(r2_score(yAL_test, pred_lasso_AL))

alphavecridgeAL = 10**np.linspace(0.01,20,2000)
ridge_AL = RidgeCV(alphas = alphavecridgeAL, cv=10) 
ridge_AL.fit(XAL_train, yAL_train)
print(list(zip(XAL_test.columns, ridge_AL.coef_)))
pred_ridge_AL = ridge_AL.predict(XAL_test)
lr_AL_ridge = Ridge(alpha = ridge_AL.alpha_)
print(r2_score(yAL_test, pred_ridge_AL))
list(zip(XAL_train.columns, lasso_model_AL.coef_))
# Out:
# [('df3', 0.0), ('ALBRKaçılış', 0.0), ('ALBRKyüksek', 0.026690740479678957), ('ALBRKdüşük', 0.025094279342621036), ('AKBNKaçılış', -0.0), ('GARANaçılış', 0.08362368275931382), ('GARANyüksek', 0.14278003217244029), ('YKBNKaçılış', 0.0), ('QNBFBaçılış', -0.002329887435286899), ('QNBFByüksek', -0.001048114856745463), ('QNBFBdüşük', 0.0021926770748760364), ('VAKBNaçılış', 0.0511215543675598), ('VAKBNyüksek', 0.04355476841935571), ('Altınyüksek', 6.63096918207558e-05), ('Gümüşaçılış', 0.0), ('Gümüşyüksek', 0.007485807905889963), ('Gümüşdüşük', 0.00890245992429588), ('Brentaçılış', -0.0022420276165931656), ('Brentyüksek', 0.0005101456768081166), ('Brentdüşük', 0.00764850281983913), ('Euroaçılış', -0.0), ('GBPyüksek', -0.0015473060346095698), ('GBPdüşük', -0.0), ('BTCaçılış', -6.963879610777733e-07), ('BTCyüksek', -2.3216420508950358e-07), ('BTCdüşük', 2.776773488676915e-07), ('ALBARAKAaçılış3', 0.011860681998944187)]
# 0.12039405336736062
# 0.40926192050737564
# ...

# %%
### GARANTİ Ridge and Lasso Regression###
XGA = df.loc[:,['df3', 'GARANaçılış','GARANyüksek', 'GARANdüşük', 'AKBNKaçılış', 'ALBRKaçılış','ALBRKyüksek', 'ALBRKdüşük',
                'YKBNKaçılış','QNBFBaçılış','QNBFByüksek', 'VAKBNaçılış','Altınyüksek', 'Altınaçılış', 'Altındüşük',
                'Gümüşyüksek', 'Gümüşaçılış', 'Gümüşdüşük','Brentdüşük', 'Euroaçılış', 'Euroyüksek', 'Eurodüşük',
                'USDaçılış', 'USDyüksek', 'USDdüşük','BTCaçılış', 'BTCyüksek', 'BTCdüşük']]
XGA['GARANaçılış3'] = XGA['GARANyüksek'] ** 2 + XGA['GARANdüşük'] * 1/2
XGA['ALBRKyüksek2'] = XGA['ALBRKyüksek'] ** 3 + XGA['GARANyüksek'] ** 2 

yGA = df['GARANşimdi']
XGA_train_val, XGA_test, yGA_train_val, yGA_test = train_test_split(XGA, yGA, test_size=0.2,random_state=42)
XGA_train, XGA_val, yGA_train, yGA_val = train_test_split(XGA_train_val, yGA_train_val, test_size=0.2, random_state=43)
alphaGA = 10**np.linspace(-5,20,2000)
lasso_GA = LassoCV(alphas = alphaGA, cv=10)
lasso_GA.fit(XGA_train, yGA_train)
lasso_model_GA = Lasso(alpha = lasso_GA.alpha_) 
lasso_model_GA.fit(XGA_train, yGA_train)
pred_lasso_GA = lasso_GA.predict(XGA_test)
print(list(zip(XGA_train.columns, lasso_model_GA.coef_)))

def mae(yGA_true, yGA_pred):
    return np.mean(np.abs(yGA_pred - yGA_true)) 

print(mae(yGA_test, pred_lasso_GA))
print(r2_score(yGA_test, pred_lasso_GA))

alphavecridgeGA = 10**np.linspace(-5,100, 2000)
ridge_GA = RidgeCV(alphas = alphavecridgeGA, cv=10) 
ridge_GA.fit(XGA_train, yGA_train)
print(list(zip(XGA_test.columns, ridge_GA.coef_)))
pred_ridge_GA = ridge_GA.predict(XGA_test)
lr_GA_ridge = Ridge(alpha = ridge_GA.alpha_)
print(mae(yGA_test, pred_ridge_GA))
print(r2_score(yGA_test, pred_ridge_GA))
# Out:
# C:\Users\EN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004863161232934843, tolerance: 0.002162244776277176
#   tol, rng, random, positive)
# C:\Users\EN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02237537293307934, tolerance: 0.002162244776277176
#   tol, rng, random, positive)
# C:\Users\EN\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022328025333285595, tolerance: 0.002162244776277176
#   tol, rng, random, positive)
# ...

# %%
### YAPIKREDİ Ridge and Lasso Regression###
XYK = df.loc[:,['df3', 'YKBNKaçılış', 'YKBNKyüksek', 'YKBNKdüşük', 'AKBNKaçılış', 'AKBNKyüksek', 'AKBNKdüşük','ALBRKaçılış', 
                'ALBRKyüksek', 'ALBRKdüşük','GARANaçılış', 'GARANyüksek', 'GARANdüşük', 'QNBFBaçılış', 'QNBFByüksek', 
                'QNBFBdüşük', 'VAKBNaçılış', 'VAKBNyüksek', 'VAKBNdüşük', 'Altınaçılış', 'Altınyüksek', 'Altındüşük',
                'Gümüşaçılış', 'Gümüşyüksek', 'Gümüşdüşük', 'Brentaçılış', 'Brentyüksek', 'Brentdüşük', 'USDaçılış',
                'USDyüksek', 'USDdüşük', 'Euroaçılış', 'Euroyüksek', 'Eurodüşük', 'GBPaçılış', 'GBPyüksek', 'GBPdüşük', 
                'BTCaçılış', 'BTCyüksek', 'BTCdüşük']]
yYK = df['YKBNKşimdi']
XYK_train_val, XYK_test, yYK_train_val, yYK_test = train_test_split(XYK, yYK, test_size=0.2,random_state=42)
XYK_train, XYK_val, yYK_train, yYK_val = train_test_split(XYK_train_val, yYK_train_val, test_size=0.2, random_state=43)
alphaYK = 10**np.linspace(-5,10,200)
lasso_YK = LassoCV(alphas = alphaYK, cv=10)
lasso_YK.fit(XYK_train, yYK_train)
lasso_model_YK = Lasso(alpha = lasso_YK.alpha_) 
lasso_model_YK.fit(XYK_train, yYK_train)
pred_lasso_YK = lasso_YK.predict(XYK_test)
print(list(zip(XYK_train.columns, lasso_model_YK.coef_)))

def mae(yYK_true, yYK_pred):
    return np.mean(np.abs(yYK_pred - yYK_true)) 

print(mae(yYK_test, pred_lasso_YK))
print(r2_score(yYK_test, pred_lasso_YK))

alphavecridgeYK = 10**np.linspace(0.01,100, 200)
ridge_YK = RidgeCV(alphas = alphavecridgeYK, cv=10) 
ridge_YK.fit(XYK_train, yYK_train)
print(list(zip(XYK_test.columns, ridge_YK.coef_)))
pred_ridge_YK = ridge_YK.predict(XYK_test)
lr_YK_ridge = Ridge(alpha = ridge_YK.alpha_)
print(mae(yYK_test, pred_ridge_YK))
print(r2_score(yYK_test, pred_ridge_YK))
# Out:
# [('df3', 0.0), ('YKBNKaçılış', 0.0), ('YKBNKyüksek', 0.0), ('YKBNKdüşük', 0.0), ('AKBNKaçılış', 0.0), ('AKBNKyüksek', 0.0), ('AKBNKdüşük', 0.0), ('ALBRKaçılış', -0.0), ('ALBRKyüksek', 0.0), ('ALBRKdüşük', 0.0), ('GARANaçılış', 0.0), ('GARANyüksek', 0.0), ('GARANdüşük', 0.0), ('QNBFBaçılış', -0.0), ('QNBFByüksek', -0.0), ('QNBFBdüşük', -0.0), ('VAKBNaçılış', 0.0), ('VAKBNyüksek', 0.0), ('VAKBNdüşük', 0.0), ('Altınaçılış', -0.0), ('Altınyüksek', 4.030964931600995e-06), ('Altındüşük', -0.0), ('Gümüşaçılış', 0.0), ('Gümüşyüksek', 0.0), ('Gümüşdüşük', 0.0), ('Brentaçılış', 0.0), ('Brentyüksek', 0.0), ('Brentdüşük', 0.005793445489789435), ('USDaçılış', -0.0), ('USDyüksek', 0.0), ('USDdüşük', -0.0), ('Euroaçılış', -0.0), ('Euroyüksek', 0.0), ('Eurodüşük', 0.0), ('GBPaçılış', -0.0), ('GBPyüksek', -0.0), ('GBPdüşük', -0.0), ('BTCaçılış', 2.217565056894669e-06), ('BTCyüksek', 1.1453286355116292e-06), ('BTCdüşük', 3.721784109412449e-06)]
# 0.19163142011812767
# 0.03813878611365906
# ...

# %%
### QNBFB Ridge and Lasso Regression###
XQN = df.loc[:,['df3', 'QNBFBaçılış', 'QNBFByüksek', 'QNBFBdüşük', 'AKBNKaçılış', 'AKBNKyüksek', 'AKBNKdüşük','ALBRKaçılış',
                'ALBRKyüksek', 'ALBRKdüşük','GARANaçılış',  'GARANyüksek', 'GARANdüşük', 'YKBNKaçılış', 'YKBNKyüksek', 
                'YKBNKdüşük', 'VAKBNaçılış', 'VAKBNyüksek', 'VAKBNdüşük', 'Altınaçılış', 'Altınyüksek', 'Altındüşük',
                'Gümüşaçılış', 'Gümüşyüksek', 'Gümüşdüşük', 'Brentaçılış', 'Brentyüksek', 'Brentdüşük', 'Euroaçılış', 
                'Euroyüksek', 'Eurodüşük', 'GBPaçılış', 'GBPyüksek', 'GBPdüşük', 'BTCaçılış', 'BTCyüksek', 'BTCdüşük']]
yQN = df['QNBFBşimdi']
XQN_train_val, XQN_test, yQN_train_val, yQN_test = train_test_split(XQN, yQN, test_size=0.2,random_state=42)
XQN_train, XQN_val, yQN_train, yQN_val = train_test_split(XQN_train_val, yQN_train_val, test_size=0.2, random_state=43)
alphaQN = 10**np.linspace(-2,2,200)
lasso_QN = LassoCV(alphas = alphaQN, cv=10)
lasso_QN.fit(XQN_train, yQN_train)
lasso_model_QN = Lasso(alpha = lasso_QN.alpha_) 
lasso_model_QN.fit(XQN_train, yQN_train)
pred_lasso_QN = lasso_QN.predict(XQN_test)
print(list(zip(XQN_train.columns, lasso_model_QN.coef_)))

def mae(yQN_true, yQN_pred):
    return np.mean(np.abs(yQN_pred - yQN_true)) 

print(mae(yQN_test, pred_lasso_QN))
print(r2_score(yQN_test, pred_lasso_QN))

alphavecridgeQN = 10**np.linspace(-2, 2, 200)
ridge_QN = RidgeCV(alphas = alphavecridgeQN, cv=10) 
ridge_QN.fit(XQN_train, yQN_train)
print(list(zip(XQN_test.columns, ridge_QN.coef_)))
pred_ridge_QN = ridge_QN.predict(XQN_test)
lr_QN_ridge = Ridge(alpha = ridge_QN.alpha_)
print(mae(yQN_test, pred_ridge_QN))
print(r2_score(yQN_test, pred_ridge_QN))
# Out:
# [('df3', 0.3316787080252929), ('QNBFBaçılış', 0.1821900641554214), ('QNBFByüksek', 0.059007565477674405), ('QNBFBdüşük', 0.13604284619048418), ('AKBNKaçılış', -0.44886408215081014), ('AKBNKyüksek', 0.0), ('AKBNKdüşük', 0.0), ('ALBRKaçılış', 0.0), ('ALBRKyüksek', -0.0), ('ALBRKdüşük', 0.0), ('GARANaçılış', -0.2730203264822368), ('GARANyüksek', 0.0), ('GARANdüşük', -0.0), ('YKBNKaçılış', 1.1551622167452564), ('YKBNKyüksek', 0.0), ('YKBNKdüşük', 0.0), ('VAKBNaçılış', 0.0), ('VAKBNyüksek', -0.3306517174585854), ('VAKBNdüşük', 0.4496468217922496), ('Altınaçılış', -0.0), ('Altınyüksek', -0.004288698299577897), ('Altındüşük', -0.0), ('Gümüşaçılış', 0.28538953079469), ('Gümüşyüksek', -0.3097568648082127), ('Gümüşdüşük', 0.0), ('Brentaçılış', -0.022706163869889454), ('Brentyüksek', 0.027277671752753595), ('Brentdüşük', -0.09130019327538588), ('Euroaçılış', -0.0), ('Euroyüksek', 0.0), ('Eurodüşük', 1.472069579570576), ('GBPaçılış', 1.71088573716089), ('GBPyüksek', 3.8136240442851532), ('GBPdüş
# ...

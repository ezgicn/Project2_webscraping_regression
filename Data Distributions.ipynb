# %%
import pandas as pd
import numpy as np
import scipy.stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file1 = 'C:/Users/EN/DataScienceAcademy/Project2/coviddata.csv'
Kovid = pd.DataFrame(pd.read_csv(file1))

# %%
file2 = 'C:/Users/EN/DataScienceAcademy/Project2/hisse verileri/AKBNK Geçmiş Verileri.csv'
AKBNK = pd.DataFrame(pd.read_csv(file2))
for i in range(0,len(AKBNK["Şimdi"])):
    AKBNK["Şimdi"][i]= AKBNK["Şimdi"][i].replace(",",".")
    AKBNK["Açılış"][i] = AKBNK["Açılış"][i].replace(",",".")
    AKBNK["Yüksek"][i] = AKBNK["Yüksek"][i].replace(",",".")
    AKBNK["Düşük"][i] = AKBNK["Düşük"][i].replace(",",".")
AKBNK["Şimdi"]=AKBNK["Şimdi"].astype(float)
AKBNK["Açılış"]=AKBNK["Açılış"].astype(float)
AKBNK["Yüksek"]=AKBNK["Yüksek"].astype(float)
AKBNK["Düşük"]=AKBNK["Düşük"].astype(float)

# %%
file3 = 'C:/Users/EN/DataScienceAcademy/Project2/hisse verileri/ALBRK Geçmiş Verileri.csv'
ALBRK = pd.DataFrame(pd.read_csv(file3))
for i in range(0,len(ALBRK["Şimdi"])):
    ALBRK["Şimdi"][i]= ALBRK["Şimdi"][i].replace(",",".")
    ALBRK["Açılış"][i] = ALBRK["Açılış"][i].replace(",",".")
    ALBRK["Yüksek"][i] = ALBRK["Yüksek"][i].replace(",",".")
    ALBRK["Düşük"][i] = ALBRK["Düşük"][i].replace(",",".")
ALBRK["Şimdi"]=ALBRK["Şimdi"].astype(float)
ALBRK["Açılış"]=ALBRK["Açılış"].astype(float)
ALBRK["Yüksek"]=ALBRK["Yüksek"].astype(float)
ALBRK["Düşük"]=ALBRK["Düşük"].astype(float)

# %%
file4 = 'C:/Users/EN/DataScienceAcademy/Project2/hisse verileri/GARAN Geçmiş Verileri.csv'
GARAN = pd.DataFrame(pd.read_csv(file4))
for i in range(0,len(GARAN["Şimdi"])):
    GARAN["Şimdi"][i]= GARAN["Şimdi"][i].replace(",",".")
    GARAN["Açılış"][i] = GARAN["Açılış"][i].replace(",",".")
    GARAN["Yüksek"][i] = GARAN["Yüksek"][i].replace(",",".")
    GARAN["Düşük"][i] = GARAN["Düşük"][i].replace(",",".")
GARAN["Şimdi"]=GARAN["Şimdi"].astype(float)
GARAN["Açılış"]=GARAN["Açılış"].astype(float)
GARAN["Yüksek"]=GARAN["Yüksek"].astype(float)
GARAN["Düşük"]=GARAN["Düşük"].astype(float)

# %%
file5 = 'C:/Users/EN/DataScienceAcademy/Project2/hisse verileri/HALKB Geçmiş Verileri.csv'
HALKB = pd.DataFrame(pd.read_csv(file5))
for i in range(0,len(HALKB["Şimdi"])):
    HALKB["Şimdi"][i]= HALKB["Şimdi"][i].replace(",",".")
    HALKB["Açılış"][i] = HALKB["Açılış"][i].replace(",",".")
    HALKB["Yüksek"][i] = HALKB["Yüksek"][i].replace(",",".")
    HALKB["Düşük"][i] = HALKB["Düşük"][i].replace(",",".")
HALKB["Şimdi"]=HALKB["Şimdi"].astype(float)
HALKB["Açılış"]=HALKB["Açılış"].astype(float)
HALKB["Yüksek"]=HALKB["Yüksek"].astype(float)
HALKB["Düşük"]=HALKB["Düşük"].astype(float)

# %%
file6 = 'C:/Users/EN/DataScienceAcademy/Project2/hisse verileri/QNBFB Geçmiş Verileri.csv'
QNBFB = pd.DataFrame(pd.read_csv(file6))
for i in range(0,len(QNBFB["Şimdi"])):
    QNBFB["Şimdi"][i]= QNBFB["Şimdi"][i].replace(",",".")
    QNBFB["Açılış"][i] = QNBFB["Açılış"][i].replace(",",".")
    QNBFB["Yüksek"][i] = QNBFB["Yüksek"][i].replace(",",".")
    QNBFB["Düşük"][i] = QNBFB["Düşük"][i].replace(",",".")
QNBFB["Şimdi"]=QNBFB["Şimdi"].astype(float)
QNBFB["Açılış"]=QNBFB["Açılış"].astype(float)
QNBFB["Yüksek"]=QNBFB["Yüksek"].astype(float)
QNBFB["Düşük"]=QNBFB["Düşük"].astype(float)

# %%
file7 = 'C:/Users/EN/DataScienceAcademy/Project2/hisse verileri/VAKBN Geçmiş Verileri.csv'
VAKBN = pd.DataFrame(pd.read_csv(file7))
for i in range(0,len(VAKBN["Şimdi"])):
    VAKBN["Şimdi"][i]= VAKBN["Şimdi"][i].replace(",",".")
    VAKBN["Açılış"][i] = VAKBN["Açılış"][i].replace(",",".")
    VAKBN["Yüksek"][i] = VAKBN["Yüksek"][i].replace(",",".")
    VAKBN["Düşük"][i] = VAKBN["Düşük"][i].replace(",",".")
VAKBN["Şimdi"]=VAKBN["Şimdi"].astype(float)
VAKBN["Açılış"]=VAKBN["Açılış"].astype(float)
VAKBN["Yüksek"]=VAKBN["Yüksek"].astype(float)
VAKBN["Düşük"]=VAKBN["Düşük"].astype(float)

# %%
file8 = 'C:/Users/EN/DataScienceAcademy/Project2/hisse verileri/YKBNK Geçmiş Verileri.csv'
YKBNK = pd.DataFrame(pd.read_csv(file8))
for i in range(0,len(YKBNK["Şimdi"])):
    YKBNK["Şimdi"][i]= YKBNK["Şimdi"][i].replace(",",".")
    YKBNK["Açılış"][i] = YKBNK["Açılış"][i].replace(",",".")
    YKBNK["Yüksek"][i] = YKBNK["Yüksek"][i].replace(",",".")
    YKBNK["Düşük"][i] = YKBNK["Düşük"][i].replace(",",".")
YKBNK["Şimdi"]=YKBNK["Şimdi"].astype(float)
YKBNK["Açılış"]=YKBNK["Açılış"].astype(float)
YKBNK["Yüksek"]=YKBNK["Yüksek"].astype(float)
YKBNK["Düşük"]=YKBNK["Düşük"].astype(float)

# %%
file9 = 'C:/Users/EN/DataScienceAcademy/Project2/hisse verileri/Altın Geçmiş Verileri.csv'
Altın = pd.DataFrame(pd.read_csv(file9))
for i in range(0,len(Altın["Şimdi"])):
    Altın["Şimdi"][i]= Altın["Şimdi"][i].replace(".","")
    Altın["Açılış"][i] = Altın["Açılış"][i].replace(".","")
    Altın["Yüksek"][i] = Altın["Yüksek"][i].replace(".","")
    Altın["Düşük"][i] = Altın["Düşük"][i].replace(".","")
for i in range(0,len(Altın["Şimdi"])):
    Altın["Şimdi"][i]= Altın["Şimdi"][i].replace(",",".")
    Altın["Açılış"][i] = Altın["Açılış"][i].replace(",",".")
    Altın["Yüksek"][i] = Altın["Yüksek"][i].replace(",",".")
    Altın["Düşük"][i] = Altın["Düşük"][i].replace(",",".")
        
Altın["Şimdi"]=Altın["Şimdi"].astype(float)
Altın["Açılış"]=Altın["Açılış"].astype(float)
Altın["Yüksek"]=Altın["Yüksek"].astype(float)
Altın["Düşük"]=Altın["Düşük"].astype(float)

# %%
file10 = 'C:/Users/EN/DataScienceAcademy/Project2/hisse verileri/Brent Petrol Geçmiş Verileri.csv'
Brent = pd.DataFrame(pd.read_csv(file10))
for i in range(0,len(Brent["Şimdi"])):
    Brent["Şimdi"][i]= Brent["Şimdi"][i].replace(",",".")
    Brent["Açılış"][i] = Brent["Açılış"][i].replace(",",".")
    Brent["Yüksek"][i] = Brent["Yüksek"][i].replace(",",".")
    Brent["Düşük"][i] = Brent["Düşük"][i].replace(",",".")
Brent["Şimdi"]=Brent["Şimdi"].astype(float)
Brent["Açılış"]=Brent["Açılış"].astype(float)
Brent["Yüksek"]=Brent["Yüksek"].astype(float)
Brent["Düşük"]=Brent["Düşük"].astype(float)

# %%
file11 = 'C:/Users/EN/DataScienceAcademy/Project2/hisse verileri/EURO Geçmiş Verileri.csv'
EURO = pd.read_csv(file11)
for i in range(0,len(EURO["Şimdi"])):
    EURO["Şimdi"][i]= EURO["Şimdi"][i].replace(",",".")
    EURO["Açılış"][i] = EURO["Açılış"][i].replace(",",".")
    EURO["Yüksek"][i] = EURO["Yüksek"][i].replace(",",".")
    EURO["Düşük"][i] = EURO["Düşük"][i].replace(",",".")
EURO["Şimdi"]=EURO["Şimdi"].astype(float)
EURO["Açılış"]=EURO["Açılış"].astype(float)
EURO["Yüksek"]=EURO["Yüksek"].astype(float)
EURO["Düşük"]=EURO["Düşük"].astype(float)

# %%
file12 = 'C:/Users/EN/DataScienceAcademy/Project2/hisse verileri/GBP Geçmiş Verileri.csv'
GBP = pd.read_csv(file12)
for i in range(0,len(GBP["Şimdi"])):
    GBP["Şimdi"][i]= GBP["Şimdi"][i].replace(",",".")
    GBP["Açılış"][i] = GBP["Açılış"][i].replace(",",".")
    GBP["Yüksek"][i] = GBP["Yüksek"][i].replace(",",".")
    GBP["Düşük"][i] = GBP["Düşük"][i].replace(",",".")
GBP["Şimdi"]=GBP["Şimdi"].astype(float)
GBP["Açılış"]=GBP["Açılış"].astype(float)
GBP["Yüksek"]=GBP["Yüksek"].astype(float)
GBP["Düşük"]=GBP["Düşük"].astype(float)

# %%
file13 = 'C:/Users/EN/DataScienceAcademy/Project2/hisse verileri/Gümüş Geçmiş Verileri.csv'
Gümüş = pd.DataFrame(pd.read_csv(file13))
for i in range(0,len(Gümüş["Şimdi"])):
    Gümüş["Şimdi"][i]= Gümüş["Şimdi"][i].replace(",",".")
    Gümüş["Açılış"][i] = Gümüş["Açılış"][i].replace(",",".")
    Gümüş["Yüksek"][i] = Gümüş["Yüksek"][i].replace(",",".")
    Gümüş["Düşük"][i] = Gümüş["Düşük"][i].replace(",",".")
Gümüş["Şimdi"]=Gümüş["Şimdi"].astype(float)
Gümüş["Açılış"]=Gümüş["Açılış"].astype(float)
Gümüş["Yüksek"]=Gümüş["Yüksek"].astype(float)
Gümüş["Düşük"]=Gümüş["Düşük"].astype(float)

# %%
file14 = 'C:/Users/EN/DataScienceAcademy/Project2/hisse verileri/USD Geçmiş Verileri.csv'
USD = pd.DataFrame(pd.read_csv(file14))
for i in range(0,len(USD["Şimdi"])):
    USD["Şimdi"][i]= USD["Şimdi"][i].replace(",",".")
    USD["Açılış"][i] = USD["Açılış"][i].replace(",",".")
    USD["Yüksek"][i] = USD["Yüksek"][i].replace(",",".")
    USD["Düşük"][i] = USD["Düşük"][i].replace(",",".")
USD["Şimdi"]=USD["Şimdi"].astype(float)
USD["Açılış"]=USD["Açılış"].astype(float)
USD["Yüksek"]=USD["Yüksek"].astype(float)
USD["Düşük"]=USD["Düşük"].astype(float)

# %%
file15 = 'C:/Users/EN/DataScienceAcademy/Project2/hisse verileri/BTC Geçmiş Verileri.csv'
BTC = pd.DataFrame(pd.read_csv(file15))
for i in range(0,len(BTC["Şimdi"])):
    BTC["Şimdi"][i]= BTC["Şimdi"][i].replace(".","")
    BTC["Açılış"][i] = BTC["Açılış"][i].replace(".","")
    BTC["Yüksek"][i] = BTC["Yüksek"][i].replace(".","")
    BTC["Düşük"][i] = BTC["Düşük"][i].replace(".","")
for i in range(0,len(BTC["Şimdi"])):
    BTC["Şimdi"][i]= BTC["Şimdi"][i].replace(",",".")
    BTC["Açılış"][i] = BTC["Açılış"][i].replace(",",".")
    BTC["Yüksek"][i] = BTC["Yüksek"][i].replace(",",".")
    BTC["Düşük"][i] = BTC["Düşük"][i].replace(",",".")      
BTC["Şimdi"]=BTC["Şimdi"].astype(float)
BTC["Açılış"]=BTC["Açılış"].astype(float)
BTC["Yüksek"]=BTC["Yüksek"].astype(float)
BTC["Düşük"]=BTC["Düşük"].astype(float)

# %%
###Distribution plots###
plt.figure(figsize=[8,10])
plt.subplot(3,2,1)
###AKBNK###
sns.kdeplot(AKBNK['Şimdi'])
sns.kdeplot(AKBNK['Açılış'])
sns.kdeplot(AKBNK['Yüksek'])
sns.kdeplot(AKBNK['Düşük'])
plt.title('AKBANK',fontsize = 12, weight='bold')

###ALBRK###
plt.subplot(3,2,2)
sns.kdeplot(ALBRK['Şimdi'])
sns.kdeplot(ALBRK['Açılış'])
sns.kdeplot(ALBRK['Yüksek'])
sns.kdeplot(ALBRK['Düşük'])
plt.title('ALBARAKA',fontsize = 12, weight='bold')

###GARAN###
plt.subplot(3,2,3)
sns.kdeplot(GARAN['Şimdi'])
sns.kdeplot(GARAN['Açılış'])
sns.kdeplot(GARAN['Yüksek'])
sns.kdeplot(GARAN['Düşük'])
plt.title('GARANTİ',fontsize = 12, weight='bold')

###HALKB###
plt.subplot(3,2,4)
sns.kdeplot(YKBNK['Şimdi'])
sns.kdeplot(YKBNK['Açılış'])
sns.kdeplot(YKBNK['Yüksek'])
sns.kdeplot(YKBNK['Düşük'])
plt.title('YAPIKREDİ',fontsize = 12, weight='bold')

###QNBFB###
plt.subplot(3,2,5)
sns.kdeplot(QNBFB['Şimdi'])
sns.kdeplot(QNBFB['Açılış'])
sns.kdeplot(QNBFB['Yüksek'])
sns.kdeplot(QNBFB['Düşük'])
plt.title('QNBFİNANS',fontsize = 12, weight='bold')

###VAKBN###
plt.subplot(3,2,6)
sns.kdeplot(VAKBN['Şimdi'])
sns.kdeplot(VAKBN['Açılış'])
sns.kdeplot(VAKBN['Yüksek'])
sns.kdeplot(VAKBN['Düşük'])
plt.title('VAKIFBANK',fontsize = 12, weight='bold')

# %%
###Commodities###
plt.figure(figsize=[8,10])
plt.subplot(3,1,1)
###Gold(Altın)###
sns.kdeplot(Altın['Şimdi'])
sns.kdeplot(Altın['Açılış'])
sns.kdeplot(Altın['Yüksek'])
sns.kdeplot(Altın['Düşük'])
plt.title('Altın',fontsize = 12, weight='bold')

##Silver(Gümüş)###
plt.subplot(3,1,2)
sns.kdeplot(Gümüş['Şimdi'])
sns.kdeplot(Gümüş['Açılış'])
sns.kdeplot(Gümüş['Yüksek'])
sns.kdeplot(Gümüş['Düşük'])
plt.title('Gümüş',fontsize = 12, weight='bold')

###Brent###
plt.subplot(3,1,3)
sns.kdeplot(Brent['Şimdi'])
sns.kdeplot(Brent['Açılış'])
sns.kdeplot(Brent['Yüksek'])
sns.kdeplot(Brent['Düşük'])
plt.title('Brent Petrol',fontsize = 12, weight='bold')

# %%
###Currencies###
plt.figure(figsize=[8,10])
plt.subplot(2,2,1)
sns.kdeplot(USD['Şimdi'])
sns.kdeplot(USD['Açılış'])
sns.kdeplot(USD['Yüksek'])
sns.kdeplot(USD['Düşük'])
plt.title('Dolar',fontsize = 12, weight='bold')

plt.subplot(2,2,2)
sns.kdeplot(EURO['Şimdi'])
sns.kdeplot(EURO['Açılış'])
sns.kdeplot(EURO['Yüksek'])
sns.kdeplot(EURO['Düşük'])
plt.title('Euro',fontsize = 12, weight='bold')

plt.subplot(2,2,3)
sns.kdeplot(GBP['Şimdi'])
sns.kdeplot(GBP['Açılış'])
sns.kdeplot(GBP['Yüksek'])
sns.kdeplot(GBP['Düşük'])
plt.title('Sterlin',fontsize = 12, weight='bold')

###Bitcoin###
plt.subplot(2,2,4)
sns.kdeplot(BTC['Şimdi'])
sns.kdeplot(BTC['Açılış'])
sns.kdeplot(BTC['Yüksek'])
sns.kdeplot(BTC['Düşük'])
plt.title('Bitcoin',fontsize = 12, weight='bold')
